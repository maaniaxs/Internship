# %%
#
import selenium
import pandas as pd

# %%
from selenium import webdriver

from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# driver = webdriver.Chrome(r'C:\Users\acer\INTERNSHIP_WORSHEET\chromedriver.exe')

# %%
import requests
import time

# %% [markdown]
# Q-1. Scrape the details of most viewed videos on YouTube from Wikipedia.
#   Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#   You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) View

# %%
driver = webdriver.Chrome(r'C:\Users\acer\INTERNSHIP_WORSHEET\chromedriver.exe')

# %%
# go to the link from where we scrapping data 
driver.get(' https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
# scrapping 'most_viewed_videos' from wikipedia
video= driver.find_elements(By.TAG_NAME,'td')   

Most_Viewed_Youtube_Videos= pd.DataFrame({})    # make dataframe

wiki = []
for i in video:
#    print(i.text.split('\n'))

    wiki.append(i.text.split('\n')[0])
    
Most_Viewed_Youtube_Videos['Rank'] = wiki[2:182:6]         # Rank of videos
Most_Viewed_Youtube_Videos['Name'] = wiki[3:182:6]          # Song name
Most_Viewed_Youtube_Videos['Artist']= wiki[4:182:6]              #    Artist name
Most_Viewed_Youtube_Videos['Viewers_in_Billion'] = wiki[5:182:6]       #  Viewers_in_Billion
Most_Viewed_Youtube_Videos['Upload_Date'] = wiki[6:182:6]                  # Upload_Date of Videos

# %%
Most_Viewed_Youtube_Videos
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.                                "Uptown Funk"[22]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9   10.   "Masha and the Bear – Recipe for Disaster"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# ...

# %%
driver.close()

#   Q 1. completed

# %% [raw]
# Q-2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1
# st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code

# %%
#1  
driver = webdriver.Chrome(r'C:\Users\acer\INTERNSHIP_WORSHEET\chromedriver.exe')

# %%
#2  GO THE WEB_PAGE
driver.get('https://www.bcci.tv/')

# %%
#3      click to the fixture
driver.find_element(By.XPATH,'/html/body/div[5]/div/div[2]/div/div[2]/div/div[1]/div[2]/a').click()

# %%
#4    AGAIN CLICK MORE FIXTURE
driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div[2]/div/button').click()

# %%
#
c= driver.find_elements(By.TAG_NAME,'h5')   #  scrapping details team India’s international fixtures from 'bcci.TV' webpage
ipl= []
for i in c:
    ipl.append(i.text)
date= ipl[2::6]                 # Series's play Date
time= ipl[3::6]                 # Series's play Time
Series = ipl[1::6]              #  Series's name


p =driver.find_elements(By.TAG_NAME,'span')
match= []
for i in p:
    match.append(i.text.split('\n')[0])
match_title=  match[13:93:6]                #  match_title
place= match[14:93:6]                       #  Seris where would be play

# %%
#6 make a DataFrame
Team_india= pd.DataFrame({'Date':date,'Time':time,'Place':place,'Match_title':match_title,'Series':Series})
Team_india
# Out:
#            Date          Time  \
# 0   18 AUG 2022  12:45 PM IST
# 1   20 AUG 2022  12:45 PM IST
# 2   22 AUG 2022  12:45 PM IST
# 3   28 AUG 2022   7:30 PM IST
# 4   31 AUG 2022   7:30 PM IST
# 5   20 SEP 2022   7:30 PM IST
# 6   23 SEP 2022   7:30 PM IST
# 7   25 SEP 2022   7:30 PM IST
# 8   28 SEP 2022   7:30 PM IST
# 9    2 OCT 2022   7:30 PM IST
# 10   4 OCT 2022   7:30 PM IST
# 11   6 OCT 2022   1:30 PM IST
# 12   9 OCT 2022   1:30 PM IST
# 13  11 OCT 2022   1:30 PM IST
#
#                                                 Place Match_title  \
# 0                                 Harare Sports Club,   1st ODI -
# 1                                 Harare Sports Club,   2nd ODI -
# 2                                 Harare Sports Club,   3rd ODI -
# 3                Dubai International Cricket Stadium,  1st T20I -
# 4                Dubai International Cricket Stadium,  2nd T20I -
# 5       Punjab Cricket Association IS Bindra Stadium,  1st T20I -
# ...

# %%
driver.close()

#   Q-2. COMPLETED

# %% [raw]
# Q-3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
#     Note: - From guru99 home page you have to reach to selenium exception handling page through code

# %%
#
driver = webdriver.Chrome(r'C:\Users\acer\INTERNSHIP_WORSHEET\chromedriver.exe')

# %%
# go to the webpage
driver.get('https://www.guru99.com/')

# %%
# clicking selenium option
driver.find_element_by_xpath('/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[2]/div[1]/div/ul[1]/li[3]/a').click()

# %%
# click on selenium exception 
driver.find_element_by_xpath('/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a').click()

# %%
excep = driver.find_elements_by_tag_name('tr')

exception_name= []
description= []
for i in excep:
    exception_name.append(re.split(r'\s',i.text, maxsplit=1)[0])     # exception name
    description.append(re.split(r'\s',i.text, maxsplit=1)[1])        #   exception description

# %%
selenium= pd.DataFrame({'Exception':exception_name, 'Description':description})
selenium
# Out:
#                               Exception  \
# 0                             Exception
# 1            ElementNotVisibleException
# 2         ElementNotSelectableException
# 3                NoSuchElementException
# 4                  NoSuchFrameException
# 5               NoAlertPresentException
# 6                 NoSuchWindowException
# 7        StaleElementReferenceException
# 8              SessionNotFoundException
# 9                      TimeoutException
# 10                   WebDriverException
# 11            ConnectionClosedException
# 12     ElementClickInterceptedException
# 13      ElementNotInteractableException
# 14             ErrorInResponseException
# 15  ErrorHandler.UnknownServerException
# 16         ImeActivationFailedException
# 17             ImeNotAvailableException
# 18         InsecureCertificateException
# 19             InvalidArgumentException
# 20         InvalidCookieDomainException
# 21          InvalidCoordinatesException
# ...

# %%
driver.close()

#    Q-3.  COMPLETED

# %% [markdown]
# Q-4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)
# D) GSDP(17-18)
# E) Share(2017)
# F) GDP($ billion)
#     Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
#
driver4 = webdriver.Chrome(r'C:\Users\acer\INTERNSHIP_WORSHEET\chromedriver.exe')

# %%
# go to the web_page
driver4.get('http://statisticstimes.com/')

# %%
# click on economic option
driver4.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button').click()

# %%
# selecting INDIA  
driver4.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]').click()

# %%
# click on  GDP STATE WISE
driver4.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a').click()

# %%
#
URL= [driver4.find_elements(By.XPATH,'//td[@class= "data1"]'), driver4.find_elements(By.XPATH,'//td[@class= "name"]'),
      driver4.find_elements(By.XPATH,'//td[@class= "data sorting_1"]')]

info = []
for i in URL:
    for n in i:
        info.append(n.text)
        
Rank= info[0:33]              #   state Rank
State= info[68:101]           #   State Name
GSDP18_19= info[136:169]         #    GSDP 18-19

# %%
#
r = driver4.find_elements(By.XPATH,'//td[@class= "data"]')
gd= []
for i in r:
    gd.append(i.text)
share18_19 = gd[1:165:5]      #  SHARE 18-19
GDP2019 = gd[2:165:5]         # GDP 2019
GSDP19_20 = gd[0:165:5]         #  GSDP 19-20

# %%
economic= pd.DataFrame({'Rank':Rank,'State':State,'GSDP-18_19':GSDP18_19,'GSDP19_20':GSDP19_20,'GDP-2019':GDP2019,'share-18_19':share18_19})
economic
# Out:
#    Rank                      State GSDP-18_19  GSDP19_20 GDP-2019 share-18_19
# 0     1                Maharashtra  2,632,792          -  399.921      13.94%
# 1     2                 Tamil Nadu  1,630,208  1,845,853  247.629       8.63%
# 2     3              Uttar Pradesh  1,584,764  1,687,818  240.726       8.39%
# 3     4                    Gujarat  1,502,899          -  228.290       7.96%
# 4     5                  Karnataka  1,493,127  1,631,977  226.806       7.91%
# 5     6                West Bengal  1,089,898  1,253,832  165.556       5.77%
# 6     7                  Rajasthan    942,586  1,020,989  143.179       4.99%
# 7     8             Andhra Pradesh    862,957    972,782  131.083       4.57%
# 8     9                  Telangana    861,031    969,604  130.791       4.56%
# 9    10             Madhya Pradesh    809,592    906,672  122.977       4.29%
# 10   11                     Kerala    781,653          -  118.733       4.14%
# ...

# %%
driver4.close()

#  Q-4.  COMPLETED

# %% [raw]
# Q-5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
#
#     Note: - From the home page you have to click on the trending option from Explore menu through code

# %%
#
driver = webdriver.Chrome(r'C:\Users\acer\INTERNSHIP_WORSHEET\chromedriver.exe')

# %%
# GO TO THE GITHUB.COM WEB PAGE
driver.get('https://github.com/')

# %%
#  CLICK ON THE EXPLORE OPTION
driver.find_element(By.XPATH, '/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary').click()

# %%
#  now click on trending repositories
driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a').click()

# %%
tag= driver.find_elements(By.XPATH,'//p[@class= "col-9 color-fg-muted my-1 pr-4"]')  # repository description
description= []
for i in tag:
    description.append(i.text.split('\n'))
    
tag= driver.find_elements(By.XPATH,'//span[@itemprop= "programmingLanguage"]')    # repository  langauge
LANGUAGE= []
for i in tag:
    LANGUAGE.append(i.text)
    
tag= driver.find_elements(By.XPATH,'//h1[@class= "h3 lh-condensed"]')   #  repository 
repository= []
for i in tag:
    repository.append(i.text)

# %%
#
print(len(repository),len(LANGUAGE), len(description))
# Out:
# 25 21 24

# %% [raw]
# Q-6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
#     Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver6 = webdriver.Chrome(r'C:\Users\acer\INTERNSHIP_WORSHEET\chromedriver.exe')

# %%
# go to the webpage 
driver6.get('https://www.billboard.com/')

# %%
#  clicking top 100 songs
driver6.find_element(By.XPATH,'/html/body/div[3]/header/div[2]/div/nav/ul/li[1]').click()

# %%
# scrapping 'songs_name','artist','last_week_rank',.. of top 100 pop songs from 'billbord.com'

nam= driver6.find_elements_by_tag_name('ul')
top= []
for i in nam:
    top.append(i.text.split('\n'))
# creating empty list for appending data    
Songs_name= []
Artist= []
Last_week_rank= []
Peak_rank= []
Weeks_on_board= []

for i in top[7:305:3]:
    Songs_name.append(i[0])        #   top 100 songs_name
    Artist.append(i[1])             #  artist name
    Last_week_rank.append(i[2])      #  Last_week_rank
    Peak_rank.append(i[3])           #    Peak_rank
    Weeks_on_board.append(i[4])         #   Weeks_on_board

# %%
pd.DataFrame({'Songs_name':Songs_name,'Artist':Artist,'Last_week_rank':Last_week_rank,
              'Peak_rank':Peak_rank,'Weeks_on_board':Weeks_on_board})
# Out:
#                                 Songs_name                         Artist  \
# 0                          About Damn Time                          Lizzo
# 1                                As It Was                   Harry Styles
# 2   Running Up That Hill (A Deal With God)                      Kate Bush
# 3                              First Class                    Jack Harlow
# 4                               Wait For U  Future Featuring Drake & Tems
# ..                                     ...                            ...
# 95                             Te Felicito       Shakira & Rauw Alejandro
# 96                     Are You Entertained              Russ & Ed Sheeran
# 97            Bzrp Music Sessions, Vol. 52             Bizarrap & Quevedo
# 98                                Right On                       Lil Baby
# 99                            La Corriente          Bad Bunny & Tony Dize
#
#    Last_week_rank Peak_rank Weeks_on_board
# ...

# %%
driver6.close()

#  Q-6. COMPLETED

# %% [raw]
# Q-7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/hr-recruiters-consultants
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
#     Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
#         click on search. All this should be done through code

# %%
driver7 = webdriver.Chrome(r'C:\Users\acer\INTERNSHIP_WORSHEET\chromedriver.exe')

# %%
#go to the wepage 
driver7.get('https://www.naukri.com/hr-recruiters-consultants')

# %%
#  clicking data scientist 
ds_recruiter= driver7.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input')
ds_recruiter.send_keys('data scientist')
ds_recruiter.send_keys(Keys.ENTER)

# %%
# scrapping  details of Data science recruiters from web_page as. name, company, location, skills, desgination 

name = driver7.find_elements_by_xpath('//a[@class= "ellipsis"]')
com= []
for i in name:
    com.append(i.text)
Name= com[0::2]                #   recruiter name
Company= com[1::2]             #   company name

s = driver7.find_elements_by_xpath('//div[@class= "hireSec highlightable"]')   # scrapping skills
Skill = []
for i in s:
    Skill.append(i.text)
    
l = driver7.find_elements_by_xpath('//small[@class= "ellipsis"]')  # scrapping  location
Location= []
for i in l:
    Location.append(i.text)
    
d = driver7.find_elements_by_xpath('//span[@class= "ellipsis clr"]')  # scrapping  Designation
Designation= []
for i in d:
    Designation.append(i.text)

# %%
print('Name=',len(Name),'\n','Company=',len(Company),'\n','Skill=',len(Skill),'\n','Location',len(Location),'\n','Designation=',len(Designation))
# Out:
# Name= 50
#  Company= 50
#  Skill= 50
#  Location 49
#  Designation= 50

# %%
driver7.close()

#     Q-7. COMPLETED

# %% [raw]
# Q-8. Scrape the details of Highest selling novels.
# URL = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
driver = webdriver.Chrome(r'C:\Users\acer\INTERNSHIP_WORSHEET\chromedriver.exe')

# %%
#   go to the webpage
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
#  scrapping the Highest selling novels data from web elements
novel= driver.find_elements_by_tag_name('td')
Novel= []
for i in novel:
    Novel.append(i.text.split('\n')[0])

# %%
# storing the Highest selling novels data

Book_name = (Novel[2::6])
Author = (Novel[3::6])
Volumes_sold = (Novel[4::6])
Publisher = (Novel[5::6])
Genre = (Novel[6::6])

# %%
pd.DataFrame({'Book_name':Book_name,'Author':Author,'Volumes_sold':Volumes_sold, 'Publisher':Publisher,'Genre':Genre})
# Out:
#                                             Book_name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes_sold        Publisher                        Genre
# ...

# %%
driver.close()

#    Q-8. completed

# %% [raw]
# Q-9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Vote

# %%
driver9 = webdriver.Chrome(r'C:\Users\acer\INTERNSHIP_WORSHEET\chromedriver.exe')

# %%
# go to link
driver9.get('https://www.imdb.com/list/ls095964455/')

# %%
#   scarpping most watched tv_series  'NAME', 'YEAR'
Name = []
Year_span = []
name= driver9.find_elements(By.TAG_NAME,'h3')
for i in name:    
    Year_span.append(i.text.split(' (')[1][0:-1])
    Name.append(i.text.split(' (')[0][3:])

# %%
Ratings = []          #  creating empty list 
Genre = []            #
Runtime = []           #
Vote = []              #

rate= driver9.find_elements_by_xpath('//div[@class= "ipl-rating-star small"]')  # Ratings 
for i in rate:
    Ratings.append(i.text)
    
gen= driver9.find_elements_by_xpath('//span[@class= "genre"]')    #  Genre 
for g in gen:
    Genre.append(g.text)
    
time= driver9.find_elements_by_xpath('//span[@class= "runtime"]')    #  Runtime
for g in time:
    Runtime.append(g.text)
    
vote = driver9.find_elements_by_xpath('//span[@name= "nv"]')    #  Vote
for g in vote:
    Vote.append(g.text)

# %%
tv_series= pd.DataFrame({'Name':Name,'Year':Year_span,'Genre':Genre,'Runtime':Runtime,'Ratings':Ratings,'Vote':Vote})

# %%
tv_series.head(100)
# Out:
#                                Name       Year                     Genre  \
# 0                   Game of Thrones  2011–2019  Action, Adventure, Drama
# 1                   Stranger Things     2016–     Drama, Fantasy, Horror
# 2                  The Walking Dead  2010–2022   Drama, Horror, Thriller
# 3                    13 Reasons Why  2017–2020  Drama, Mystery, Thriller
# 4                           The 100  2014–2020    Drama, Mystery, Sci-Fi
# ..                              ...        ...                       ...
# 95                            Reign  2013–2017                     Drama
# 96   A Series of Unfortunate Events  2017–2019  Adventure, Comedy, Drama
# 97                   Criminal Minds  2005–2020     Crime, Drama, Mystery
# 98            Scream: The TV Series  2015–2019      Comedy, Crime, Drama
# 99     . The Haunting of Hill House       2018    Drama, Horror, Mystery
#
#     Runtime Ratings       Vote
# 0    57 min     9.2  2,019,793
# ...

# %%
driver9.close()

#   Q9. completed

# %% [markdown]
# Q-10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
driver = webdriver.Chrome(r'C:\Users\acer\INTERNSHIP_WORSHEET\chromedriver.exe')

# %%
#  GOTO THE web page
driver.get('https://archive.ics.uci.edu/')

# %%
# click to the view all datasets
driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/span/b/a').click()

# %%
dataset= driver.find_elements_by_xpath('//p[@class= "normal"]')

uci= []
for i in dataset:
    uci.append(i.text)
    
Name= uci[8:4362:7]              #      Dataset's name
year= uci[14::7]             #      Year
data_types= uci[9:4362:7]        #      Data_types
task = uci[10::7]             #     Task
attribute_type= uci[11::7]    #      Attribute types
instances= uci[12::7]         #      no. of Instances
attribute= uci[13::7]          #     Attribute

# %%
ML_Dataset= pd.DataFrame({'Name':Name,'Data_types':data_types,'Task':task,'Attribute_type':attribute_type,
              'Instances':instances,'attribute':attribute,'Year':year})
ML_Dataset
# Out:
#                                                   Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                      Data_types                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...

# %%
ML_Dataset.shape
#ML_Dataset.to_csv('UCI_ML_Dataset.csv')
# Out:
# (622, 7)

# %%
driver.close()

#  Q-10.  COMPLETED
